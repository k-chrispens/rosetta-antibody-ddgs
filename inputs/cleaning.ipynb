# %%
import re
from pyrosetta import *
from pyrosetta.rosetta.core.import_pose import *
import pandas as pd
pyrosetta.init()
# Out:
# PyRosetta-4 2022 [Rosetta PyRosetta4.Release.python36.linux 2022.14+release.d95c9420af12eca758935f7e2b4d05be19e3a5fe 2022-04-07T08:56:27] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.Release.python36.linux r316 2022.14+release.d95c942 d95c9420af12eca758935f7e2b4d05be19e3a5fe http://www.pyrosetta.org 2022-04-07T08:56:27
# core.init: command: PyRosetta -ex1 -ex2aro -database /projects/kasp8735/software/anaconda3/envs/cenv_flu2/lib/python3.6/site-packages/pyrosetta-2022.14+release.d95c942-py3.6-linux-x86_64.egg/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-475452717 seed_offset=0 real_seed=-475452717
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-475452717 RG_type=mt19937

# %%
data = pd.read_csv("../raw_datasets/use_this_data.csv")
pdbs = data["#PDB"].unique()

# %%
poses = []
for pdb in pdbs:
    print(pdb)
    pose = get_pdb_and_cleanup(f"{pdb}_all.pdb")
    pose.dump_pdb(f"{pdb}_all.clean.pdb")
# Out:
# 1DQJ
# core.chemical.GlobalResidueTypeSet: Finished initializing fa_standard residue type set.  Created 983 residue types
# core.chemical.GlobalResidueTypeSet: Total time to initialize 1.4 seconds.
# core.import_pose.import_pose: File '1DQJ_all.pdb' automatically determined to be of type PDB
# core.conformation.Conformation: Found disulfide between residues 6 127
# core.conformation.Conformation: current variant for 6 CYS
# core.conformation.Conformation: current variant for 127 CYS
# core.conformation.Conformation: current variant for 6 CYD
# core.conformation.Conformation: current variant for 127 CYD
# core.conformation.Conformation: Found disulfide between residues 30 115
# core.conformation.Conformation: current variant for 30 CYS
# core.conformation.Conformation: current variant for 115 CYS
# core.conformation.Conformation: current variant for 30 CYD
# core.conformation.Conformation: current variant for 115 CYD
# ...
