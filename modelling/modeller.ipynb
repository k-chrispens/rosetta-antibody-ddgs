# %% [markdown]
# # MODELLER
# Using modeller to homology model the flu antibody pdbs, as there are a few mutational differences in the stem that we may not capture.

# %%
from modeller import *

# %%
# This will read two sequences, align them, and write the alignment
# to a file:
log.verbose()
env = Environ()
env.io.atom_files_directory = ['/projects/kach6913/rosetta-antibody-ddgs/modelling/']
aln = alignment(env)
mdl = model(env, file='3GBN_all')
aln.append_model(mdl, align_codes='3GBN_all')
aln.append(file='/projects/kach6913/rosetta-antibody-ddgs/modelling/H1_PDB_toalign.seq', align_codes=('New_Caledonia_1999'))
# The as1.sim.mat similarity matrix is used by default:
aln.align(gap_penalties_1d=(-600, -400))
aln.write(file='/projects/kach6913/rosetta-antibody-ddgs/modelling/ncal-3GBN.ali', alignment_format='PIR')
aln.write(file='/projects/kach6913/rosetta-antibody-ddgs/modelling/ncal-3GBN.pap', alignment_format='PAP')
# Out:
# openf___224_> Open           $(LIB)/restyp.lib
# openf___224_> Open           ${MODINSTALL9v25}/modlib/resgrp.lib
# rdresgr_266_> Number of residue groups:        2
# openf___224_> Open           ${MODINSTALL9v25}/modlib/sstruc.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:      5091779    4972.440     4.856
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:      5092307    4972.956     4.856
# openf___224_> Open           ${MODINSTALL9v25}/modlib/resdih.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:      5140907    5020.417     4.903
# rdrdih__263_> Number of dihedral angle types         :        9
#               Maximal number of dihedral angle optima:        3
#               Dihedral angle names                   :  Alph Phi Psi Omeg chi1 chi2 chi3 chi4 chi5
# openf___224_> Open           ${MODINSTALL9v25}/modlib/radii.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:      5154207    5033.405     4.915
# openf___224_> Open           ${MODINSTALL9v25}/modlib/radii14.lib
# openf___224_> Open           ${MODINSTALL9v25}/modlib/af_mnchdef.lib
# rdwilmo_274_> Mainchain residue conformation classes:  APBLE
# openf___224_> Open           ${MODINSTALL9v25}/modlib/mnch.lib
# rdclass_257_> Number of classes:        5
# openf___224_> Open           ${MODINSTALL9v25}/modlib/mnch1.lib
# openf___224_> Open           ${MODINSTALL9v25}/modlib/mnch2.lib
# openf___224_> Open           ${MODINSTALL9v25}/modlib/mnch3.lib
# openf___224_> Open           ${MODINSTALL9v25}/modlib/xs4.mat
# rdrrwgh_268_> Number of residue types:       21
# openf___224_> Open           /projects/kach6913/rosetta-antibody-ddgs/modelling/3GBN_all.pdb
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4420537    4316.931     4.216
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4420613    4317.005     4.216
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4420784    4317.172     4.216
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4421634    4318.002     4.217
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4422892    4319.230     4.218
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4424796    4321.090     4.220
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4424836    4321.129     4.220
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4424926    4321.217     4.220
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4427782    4324.006     4.223
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4427842    4324.064     4.223
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4427977    4324.196     4.223
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4432261    4328.380     4.227
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4432349    4328.466     4.227
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4432547    4328.659     4.227
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4438973    4334.935     4.233
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4439105    4335.063     4.233
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4439402    4335.354     4.234
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4449024    4344.750     4.243
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4449224    4344.945     4.243
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4449674    4345.385     4.244
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4464124    4359.496     4.257
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4464424    4359.789     4.258
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4465099    4360.448     4.258
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4486757    4381.599     4.279
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4487205    4382.036     4.279
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4488213    4383.021     4.280
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4520717    4414.763     4.311
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4520801    4414.845     4.311
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4520801    4414.845     4.311
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4521473    4415.501     4.312
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4522985    4416.978     4.313
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4571741    4464.591     4.360
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4572749    4465.575     4.361
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4575017    4467.790     4.363
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4648151    4539.210     4.433
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4649663    4540.687     4.434
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:      4653065    4544.009     4.438
# readlinef__W> File: /projects/kach6913/rosetta-antibody-ddgs/modelling/3GBN_all.pdb, Line: 12921
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: /projects/kach6913/rosetta-antibody-ddgs/modelling/3GBN_all.pdb, Line: 12923
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: /projects/kach6913/rosetta-antibody-ddgs/modelling/3GBN_all.pdb, Line: 12924
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: /projects/kach6913/rosetta-antibody-ddgs/modelling/3GBN_all.pdb, Line: 12925
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: /projects/kach6913/rosetta-antibody-ddgs/modelling/3GBN_all.pdb, Line: 12926
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: /projects/kach6913/rosetta-antibody-ddgs/modelling/3GBN_all.pdb, Line: 12927
#               No more warnings will be printed for truncated lines in this file.
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:      5229289    5106.728     4.987
# read_mo_297_> Segments, residues, atoms:        4      812     6274
# read_mo_298_> Segment:        1     7 A   326 A     2539
# read_mo_298_> Segment:        2     1 B   173 B     1395
# read_mo_298_> Segment:        3     1 H   188 H     1210
# read_mo_298_> Segment:        4     3 L   195 L     1130
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:      4179051    4081.104     3.985
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:      4646619    4537.714     4.431
# openf___224_> Open           /projects/kach6913/rosetta-antibody-ddgs/modelling/H1_PDB_toalign.seq
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:      4886869    4772.333     4.660
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:      4888953    4774.368     4.662
#
# Read the alignment from file       : /projects/kach6913/rosetta-antibody-ddgs/modelling/H1_PDB_toalign.seq
#
# Total number of alignment positions:   812
#
#   #  Code        #_Res #_Segm PDB_code    Name
# -------------------------------------------------------------------------------
#   1   3GBN_all     812      4    3GBN_all
#   2  New_Caled     522      1        ncal
# align___276_> 'align_block' changed to 1.
# openf___224_> Open           $(LIB)/as1.sim.mat
# rdrrwgh_268_> Number of residue types:       20
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:      4893881    4779.181     4.667
#
# Pairwise dynamic programming alignment (ALIGN):
#   Residue-residue metric   : $(LIB)/as1.sim.mat
#   Diagonal                 :          100
#   Overhang                 :            0
#   Local alignment          :            F
#   MATRIX_OFFSET (local aln):       0.0000
#   N_SUBOPT                 :            0
#   SUBOPT_OFFSET            :       0.0000
#   Alignment block          :            1
#   Gap introduction penalty :    -600.0000
#   Gap extension penalty    :    -400.0000
#   Break-break bonus        :   10000.0000
#   Length of alignment      :          828
#   Score                    :  290584.0000
# openf___224_> Open           /projects/kach6913/rosetta-antibody-ddgs/modelling/ncal-3GBN.ali
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:      4900041    4785.196     4.673
# openf___224_> Open           /projects/kach6913/rosetta-antibody-ddgs/modelling/ncal-3GBN.pap

# %%
# Homology modelling by the automodel class
from modeller.automodel import * # Load the automodel class
log.verbose() # request verbose output
env = environ() # create a new MODELLER environment
a = automodel(env,
    alnfile = 'ncal-3GBN.ali', # alignment filename
    knowns = '3GBN_all', # codes of the templates
    sequence = 'ncal') # code of the target
a.starting_model= 1 # index of the first model
a.ending_model = 1 # index of the last model
# (determines how many models to calculate)
a.make() # do the actual homology modelling
